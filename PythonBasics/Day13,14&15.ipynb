# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# <h3>Plotting without scripting layer</h3>

# %%
# First let's set the backend without using mpl.use() from the scripting layer
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure
import numpy as np

# create a new figure
fig = Figure()

# associate fig with the backend
canvas = FigureCanvasAgg(fig)

# generate 10000 normaly distributed sample points 
x = np.random.randn(10000)

# add a subplot to the fig
ax = fig.add_subplot(1,1,1)

# plot the histogram for x array
ax.hist(x, 100)

# save the figure to histogram.png
ax.set_title("My First Histogram")   # set the title of the plot as "My First Histogram"
fig.savefig('histogram.png')

# %%
from IPython.display import Image
Image("histogram.png")

# %% [markdown]
# <h3>Plotting using scripting layer</h3>

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure()
x = np.random.randn(10000)
plt.hist(x, 100)
plt.title('Normal distribution')
plt.savefig('matplotlib_histogram.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h3>Display a point on a graph</h3>

# %%
#
plt.figure()
# plot the point (1.5, 1.5) using the circle marker
plt.plot(1.5, 1.5,'ro')
# plot the point (2, 2) using the circle marker
plt.plot(2, 2, 'bd')
# plot the point (2.5, 2.5) using the circle marker
plt.plot(2.5, 2.5, 'go')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h3>Labelling a graph using artist layer</h3>

# %%
#get the current axes
ax=plt.gca()

#Set axis properties[xmin,xmax,ymin,ymax]
ax.axis([0,6,0,10])
ax.set_title("My Frist Graph")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")

#get the information about each artist layer instance
ax.get_children()

#get the details of an instance need to move to that instance
ax.get_xaxis().get_children()
# Out:
# [Text(0.5, 23.52222222222222, 'X-axis'),
#  Text(1, 24.911111111111108, ''),
#  <matplotlib.axis.XTick at 0x7fa572848518>,
#  <matplotlib.axis.XTick at 0x7fa572858b70>,
#  <matplotlib.axis.XTick at 0x7fa572866550>,
#  <matplotlib.axis.XTick at 0x7fa5725fd828>,
#  <matplotlib.axis.XTick at 0x7fa5725fdeb8>,
#  <matplotlib.axis.XTick at 0x7fa572589160>,
#  <matplotlib.axis.XTick at 0x7fa5725895f8>]

# %% [markdown]
# <h3>Labelling using Scripting layer</h3>

# %%
plt.axis([0,5,0,5])
plt.title("Labelling using plt")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# Text(47.097222222222214, 0.5, 'y-axis')

# %% [markdown]
# <h3>Basic Plots Using Matplotlib</h3>

# %%
import pandas as pd
iris = pd.read_csv("iris.csv")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# <h3>1. Scatter Plots</h3>

# %%
plt.figure()
plt.scatter(iris.petal_width,iris.petal_length,s=50,c='red')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#changing the size and color of teh poimts based on species
plt.figure()
sp1 = iris[iris['species']=='setosa']
sp2 = iris[iris['species']=='virginica']
sp3 = iris[iris['species']=='versicolor']
plt.scatter(sp1['petal_width'], sp1['petal_length'], s= 25, c='red', label = 'setosa')
plt.scatter(sp2['petal_width'], sp2['petal_length'], s= 25, c='blue', label = 'virginica')
plt.scatter(sp3['petal_width'], sp3['petal_length'], s= 25, c='green', label = 'versicolor')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#giving labels
plt.title('Petal Width vs Petal Length (Iris Dataset)')
plt.xlabel('Petal Width')
plt.ylabel('Petal Length')
plt.legend(['Set','Vir','Ver'])

# %% [markdown]
# <h2>Day 14</h2>

# %% [markdown]
# <h3>Line Plot</h3>

# %%
plt.figure()
plt.plot(iris.petal_width,'r-')
#r- is solid line with red color.
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(iris.petal_width,'r-',iris.petal_length,'b-')
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.lines.Line2D at 0x7fa572181400>,
#  <matplotlib.lines.Line2D at 0x7fa572181550>]

# %% [markdown]
# <h3>Bar Chart</h3>

# %%
plt.figure()
plt.bar(iris.species,iris.petal_width, width =0.2)
bar.get
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 150 artists>

# %%
plt.figure()
plt.bar(1,sp1.petal_width, width = 0.3)
plt.bar(2,sp2.petal_width, width = 0.3)
plt.bar(3,sp3.petal_width, width = 0.3)
plt.legend(['virginica','setosa','versicolor'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.barh(1,sp1.petal_width, height = 0.3)
plt.barh(2,sp2.petal_width, height = 0.3)
plt.barh(3,sp3.petal_width, height = 0.3)
plt.legend(['virginica','setosa','versicolor'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h3>Histograms</h3>

# %%
plt.figure(figsize=(5,5))
plt.hist(iris.petal_width, bins = 10);
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# <h3>Box Plots</h3>

# %%
plt.figure()
plt.boxplot(iris.sepal_width);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.boxplot([iris.sepal_width,iris.sepal_length,iris.petal_width,iris.petal_length]);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h3>Subplots</h3>

# %%
plt.figure()
#subplot with 1 row, 2 columns and current axis is 1st subplot axis
plt.subplot(1,2,1)
plt.scatter(iris.petal_width,iris.petal_length)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.subplot(1,2,2)
plt.hist(iris.petal_width,bins = 30);

# %%
#sometimes we need to move from script layer to artist layer
#when we need to change some instance.

# %%
plt.figure()
ax1 = plt.subplot(1,2,1)
plt.scatter(iris.petal_width,iris.petal_length)
#pass (sharey=ax1) to ensure the two subplot share the same y axis
ax2=plt.subplot(1,2,2, sharey=ax1)
plt.hist(iris.petal_width,bins = 30);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
ax1 = plt.subplot(1,2,1, sharey=ax2)
plt.scatter(iris.petal_width,iris.petal_length)
#pass (sharey=ax1) to ensure the two subplot share the same y axis
ax2=plt.subplot(1,2,2)
plt.hist(iris.petal_width,bins = 30);
#yaxis will take the value with max value
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#cretae 2x2 grid of axis subplots
fig, ((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9))=plt.subplots(3,3,sharex=True)
axs=[ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9]
#draw n=10, 100, 100 and 10000 samples from the noraml distribution and plot
#corresponding histogram 
for n in range(0,len(axs)):
    sample_size = 10*(n+1)
    sample =np.random.normal(loc=0.0, scale=1.0, size =sample_size)
    axs[n].hist(sample)
    axs[n].set_title('n={}'.format(sample_size))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h2>Day 15</h2>

# %%
import matplotlib.gridspec as gridspec

# %%
# use gridspec to partition the figure into subplots
plt.figure()
gspec = gridspec.GridSpec(3, 3)

top_histogram = plt.subplot(gspec[0, 1:])
side_histogram = plt.subplot(gspec[1:, 0])
lower_right = plt.subplot(gspec[1:, 1:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
lower_right.scatter(X, Y)
top_histogram.hist(X, bins=100)
side_histogram.clear()
side_histogram.hist(Y, bins=100,orientation='horizontal')
side_histogram.invert_xaxis()

# %%
#Get and Returns the current figure object
plt.gcf()
# Out:
# <img src="data:image/png;base64,..." width="640">
